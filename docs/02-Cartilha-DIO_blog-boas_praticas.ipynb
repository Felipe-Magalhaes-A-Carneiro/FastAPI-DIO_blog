# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***Boas práticas com FastAPI***

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Por recomendação do professor, estaremos estruturando o nosso programa internamente da seguinte maneira:

# %% [markdown]
#     FastAPI-DIO_blog/
#     ├── app/
#     ├── controllers/
#     ├── docs/
#     ├── models/
#     ├── services/
#     ├── views/
#     ├── poetry.lock
#     ├── pyproject.toml
#     └── README.md

# %% [markdown]
# Colocaremos os modelos na pasta 'models' o que deixará o nosso arquiivo 'main' límpo e adequado a forma que é feito no mercado.
